# %%
import pandas as pd

# %%
products = pd.Series(
    [70000, 150, 300],
    index=['Laptop', 'Mouse', 'Keyboard']
)

# %%
products
# Out:
# Laptop      70000
# Mouse         150
# Keyboard      300
# dtype: int64

# %%
laptop_price = products.loc['Laptop']

# %%
laptop_price
# Out:
# 70000

# %%
first_two = products.iloc[0:2]

# %%
first_two
# Out:
# Laptop    70000
# Mouse       150
# dtype: int64
