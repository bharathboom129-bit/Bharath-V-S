# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    'Price': [250000, 300000, 400000, 350000, 450000, 500000, 600000, 550000, 700000, 650000],
    'SquareFootage': [1200, 1500, 2000, 1800, 2200, 2500, 3000, 2800, 3500, 3200],
    'Bedrooms': [2, 3, 3, 3, 4, 4, 5, 4, 5, 5],
    'Bathrooms': [1, 2, 2, 2, 3, 3, 4, 3, 4, 4]
}

# %%
data=pd.DataFrame(data)
data
# Out:
#     Price  SquareFootage  Bedrooms  Bathrooms
# 0  250000           1200         2          1
# 1  300000           1500         3          2
# 2  400000           2000         3          2
# 3  350000           1800         3          2
# 4  450000           2200         4          3
# 5  500000           2500         4          3
# 6  600000           3000         5          4
# 7  550000           2800         4          3
# 8  700000           3500         5          4
# 9  650000           3200         5          4

# %%
corr_matrix=data.corr()

# %%
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
high_corr = corr_matrix[(corr_matrix > 0.8) & (corr_matrix < 1.0)]
high_corr.dropna(how='all').dropna(axis=1, how='all')
sns.boxplot(y='Price', data=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 high_corr = corr_matrix[(corr_matrix > 0.8) & (corr_matrix < 1.0)]
#       2 high_corr.dropna(how='all').dropna(axis=1, how='all')
# ----> 3 sns.boxplot(y='Price', data=df)
#
# NameError: name 'df' is not defined
