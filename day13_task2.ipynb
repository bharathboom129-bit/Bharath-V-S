# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    'Price': [250000, 300000, 400000, 350000, 450000, 500000, 600000, 550000, 700000, 650000],
    'SquareFootage': [1200, 1500, 2000, 1800, 2200, 2500, 3000, 2800, 3500, 3200],
    'City': ['New York', 'Los Angeles', 'New York', 'Chicago', 'Los Angeles', 'Chicago', 'New York', 'Chicago', 'Los Angeles', 'New York']
}

# %%
df=pd.DataFrame(data)
df
# Out:
#     Price  SquareFootage         City
# 0  250000           1200     New York
# 1  300000           1500  Los Angeles
# 2  400000           2000     New York
# 3  350000           1800      Chicago
# 4  450000           2200  Los Angeles
# 5  500000           2500      Chicago
# 6  600000           3000     New York
# 7  550000           2800      Chicago
# 8  700000           3500  Los Angeles
# 9  650000           3200     New York

# %%
sns.scatterplot(x="SquareFootage",y="Price",data=df)
# Out:
# <Axes: xlabel='SquareFootage', ylabel='Price'>

# %%
sns.boxplot
