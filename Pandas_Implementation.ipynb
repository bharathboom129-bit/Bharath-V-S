# %%
import pandas as pd

# %%
import numpy as np

# %%
datas = pd.read_csv(r"C:\Users\Dell\Downloads\raw\test2.csv")

# %%
datas
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David   NaN         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
datas.isnull()
# Out:
#    Unnamed: 0   Name    Age  Department  Salary
# 0       False  False  False       False   False
# 1       False  False  False       False   False
# 2       False  False  False       False   False
# 3       False  False   True       False   False
# 4       False  False  False       False    True
# 5       False  False  False       False   False

# %%
datas
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David   NaN         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
datas.iloc[1:4,1:4]
# Out:
#       Name   Age Department
# 1      Bob  30.0         IT
# 2  Charlie  35.0    Finance
# 3    David   NaN         IT

# %%
datas.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Age', 'Department', 'Salary'], dtype='object')

# %%
datas.rename(columns={"Name":"N","Age":"A","Department":"D","Salary":"S"},inplace=True)

# %%
datas
# Out:
#    Unnamed: 0        N     A        D        S
# 0           0    Alice  25.0       HR  50000.0
# 1           1      Bob  30.0       IT  60000.0
# 2           2  Charlie  35.0  Finance  70000.0
# 3           3    David   NaN       IT  62000.0
# 4           4      Eve  29.0       HR      NaN
# 5           5    Alice  25.0       HR  50000.0

# %%
datas
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David   NaN         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
datas.drop('Unnamed: 0',axis=1,inplace=True)

# %%
datas
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David   NaN         IT  62000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  50000.0

# %%
datas["updated_salary"]=datas["Salary"]+5000

# %%
datas["updated_salary2"] = datas["Salary"].map(lambda x:x+10000)

# %%
datas
# Out:
#    Unnamed: 0     Name   Age Department   Salary Level
# 0           0    Alice  25.0         HR  50000.0   low
# 1           1      Bob  30.0         IT  60000.0  High
# 2           2  Charlie  35.0    Finance  70000.0  High
# 3           3    David   NaN         IT  62000.0  High
# 4           4      Eve  29.0         HR      NaN   low
# 5           5    Alice  25.0         HR  50000.0   low

# %%
datas.dropna(inplace=True)

# %%
datas.isnull().sum()
# Out:
# Name               0
# Age                0
# Department         0
# Salary             0
# updated_salary     0
# updated_salary2    0
# dtype: int64

# %%
datas["Age"] = datas.Age.astype("int")

# %%
datas[(datas["Salary"]>50000) | (datas["Salary"] < 65000)]
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David   NaN         IT  62000.0
# 5           5    Alice  25.0         HR  50000.0

# %%
datas
# Out:
#    Unnamed: 0     Name   Age Department   Salary Level
# 0           0    Alice  25.0         HR  50000.0   low
# 1           1      Bob  30.0         IT  60000.0  High
# 2           2  Charlie  35.0    Finance  70000.0  High
# 3           3    David   NaN         IT  62000.0  High
# 4           4      Eve  29.0         HR      NaN   low
# 5           5    Alice  25.0         HR  50000.0   low

# %%
datas.isnull().sum()
# Out:
# Unnamed: 0    0
# Name          0
# Age           1
# Department    0
# Salary        1
# Level         0
# dtype: int64

# %%
datas["Age"].mean()
# Out:
# np.float64(28.8)

# %%
datas["Age"] = datas["Age"].fillna(value=datas["Age"].mean())
datas["Salary"] = datas["Salary"].fillna(value=datas["Salary"].mean())

# %%
datas
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David  28.8         IT  62000.0
# 4           4      Eve  29.0         HR  58400.0
# 5           5    Alice  25.0         HR  50000.0

# %%
datas["Department"].value_counts()
# Out:
# Department
# HR         3
# IT         2
# Finance    1
# Name: count, dtype: int64

# %%
datas
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David   NaN         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
datas["Age"] = datas["Age"].fillna(method="ffill")
datas["Salary"] = datas["Salary"].fillna(method="bfill")
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_44816\4191250414.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   datas["Age"] = datas["Age"].fillna(method="ffill")
# C:\Users\Dell\AppData\Local\Temp\ipykernel_44816\4191250414.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   datas["Salary"] = datas["Salary"].fillna(method="bfill")

# %%
datas.Age.ffill()
# Out:
# 0    25.0
# 1    30.0
# 2    35.0
# 3    35.0
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
datas
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David  35.0         IT  62000.0
# 4           4      Eve  29.0         HR  50000.0
# 5           5    Alice  25.0         HR  50000.0

# %%
### Column wise apply()
datas["updated_salary"] = datas["Salary"].apply(lambda x:x+500)

# %%
## Row wise apply()
datas["level"] =  datas.apply(lambda s:"High" if s["updated_salary"] > 60000 else "Low" ,axis =1 )

# %%
datas
# Out:
#    Unnamed: 0     Name   Age Department   Salary  updated_salary level
# 0           0    Alice  25.0         HR  50000.0         50500.0   Low
# 1           1      Bob  30.0         IT  60000.0         60500.0  High
# 2           2  Charlie  35.0    Finance  70000.0         70500.0  High
# 3           3    David  35.0         IT  62000.0         62500.0  High
# 4           4      Eve  29.0         HR  50000.0         50500.0   Low
# 5           5    Alice  25.0         HR  50000.0         50500.0   Low

# %%
datas.groupby("Department")["Salary"].mean()
# Out:
# Department
# Finance    70000.0
# HR         50000.0
# IT         61000.0
# Name: Salary, dtype: float64
