# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\mallikarjun\OneDrive\Documents\Book1.csv")
data
# Out:
#    Location
# 0  New York
# 1  new york
# 2  NEW YORK

# %%
data["Location"].unique()
# Out:
# array(['New York', 'new york', 'NEW YORK'], dtype=object)

# %%
data["Location"] = data["Location"].str.strip()
data
# Out:
#    Location
# 0  New York
# 1  new york
# 2  NEW YORK

# %%
data["Location"]=data["Location"].str.lower()
data
# Out:
#    Location
# 0  new york
# 1  new york
# 2  new york

# %%
data["Location"].unique()
# Out:
# array(['new york'], dtype=object)
